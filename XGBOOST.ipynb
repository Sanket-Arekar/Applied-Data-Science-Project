# %%
import numpy as np
import pandas as pd
df=pd.read_csv("future_values.csv")
df
# Out:
#                  Date&Time          KW
# 0      2021-01-01 00:00:00   87.973333
# 1      2021-01-01 01:00:00   86.760000
# 2      2021-01-01 02:00:00   88.260000
# 3      2021-01-01 03:00:00   89.340000
# 4      2021-01-01 04:00:00   87.820000
# ...                    ...         ...
# 17218  2022-08-24 20:00:00  124.560000
# 17219  2022-08-24 21:00:00  122.460000
# 17220  2022-08-24 22:00:00  119.260000
# 17221  2022-08-24 23:00:00  111.400000
# 17222  2022-08-25 00:00:00  104.240000
#
# [17223 rows x 2 columns]

# %%
df_future_dates_copy = df.copy()
df_future_dates_copy
# Out:
#                  Date&Time          KW
# 0      2021-01-01 00:00:00   87.973333
# 1      2021-01-01 01:00:00   86.760000
# 2      2021-01-01 02:00:00   88.260000
# 3      2021-01-01 03:00:00   89.340000
# 4      2021-01-01 04:00:00   87.820000
# ...                    ...         ...
# 17218  2022-08-24 20:00:00  124.560000
# 17219  2022-08-24 21:00:00  122.460000
# 17220  2022-08-24 22:00:00  119.260000
# 17221  2022-08-24 23:00:00  111.400000
# 17222  2022-08-25 00:00:00  104.240000
#
# [17223 rows x 2 columns]

# %%
train_size = int(len(df) * 0.75)

# %%
df1=co

# %%
col_names = ["Date/Time", "KW"]
df = pd.read_csv("Combined.csv")
df = df.rename({'Meter ID         ': 'Meter_ID', 'Date / Time           ': 'Date&Time', 'KW(ch: 1  set:1)    ': 'KW', 'KVA(ch: 2  set:1)   ': 'KVA', 'PF(1(ch: 2  set:1)  ':'PF'}, axis='columns')
df = df[['Date&Time','KW']]
df['Date&Time'] = df['Date&Time'].apply(lambda x: x.strip())

# %%
df=pd.read_csv("dataset.csv")
df=df.dropna()

# %%
df
# Out:
#                  Date&Time      KW  Month    Year        Date  Hour      Time  \
# 0      2021-01-01 00:15:00   91.36    1.0  2021.0  2021-01-01   0.0  00:15:00
# 1      2021-01-01 00:30:00   85.04    1.0  2021.0  2021-01-01   0.0  00:30:00
# 2      2021-01-01 00:45:00   87.52    1.0  2021.0  2021-01-01   0.0  00:45:00
# 3      2021-01-01 01:00:00   87.28    1.0  2021.0  2021-01-01   1.0  01:00:00
# 4      2021-01-01 01:15:00   89.12    1.0  2021.0  2021-01-01   1.0  01:15:00
# ...                    ...     ...    ...     ...         ...   ...       ...
# 57687  2022-08-24 23:00:00  118.64    8.0  2022.0  2022-08-24  23.0  23:00:00
# 57688  2022-08-24 23:15:00  109.92    8.0  2022.0  2022-08-24  23.0  23:15:00
# 57689  2022-08-24 23:30:00  108.88    8.0  2022.0  2022-08-24  23.0  23:30:00
# 57690  2022-08-24 23:45:00  108.16    8.0  2022.0  2022-08-24  23.0  23:45:00
# 57691  2022-08-25 00:00:00  104.24    8.0  2022.0  2022-08-25   0.0  00:00:00
#
#        Week        Day
# ...

# %%
def create_features(df, target_variable):
    
    df['date'] = df.index
    df['hour'] = df['date'].dt.hour
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month'] = df['date'].dt.month
    df['year'] = df['date'].dt.year
    df['dayofyear'] = df['date'].dt.dayofyear
    df['dayofmonth'] = df['date'].dt.day
    df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear','dayofmonth','weekofyear']]
    if target_variable:
        y = df[target_variable]
        return X, y
    return X

# %%
dti = pd.date_range("2022-09-01 00:15:00", periods=1200, freq="H")
df_future_dates = pd.DataFrame(dti, columns = ['Date'])
df_future_dates['Irr'] = np.nan
df_future_dates.index = pd.to_datetime(df_future_dates['Date'], format='%Y-%m-%d %H:%M:%S')
df_future_dates_copy = df_future_dates.copy()

# %%
df_future_dates_copy
# Out:
#                                    Date  Irr
# Date
# 2022-09-01 00:15:00 2022-09-01 00:15:00  NaN
# 2022-09-01 01:15:00 2022-09-01 01:15:00  NaN
# 2022-09-01 02:15:00 2022-09-01 02:15:00  NaN
# 2022-09-01 03:15:00 2022-09-01 03:15:00  NaN
# 2022-09-01 04:15:00 2022-09-01 04:15:00  NaN
# ...                                 ...  ...
# 2022-10-20 19:15:00 2022-10-20 19:15:00  NaN
# 2022-10-20 20:15:00 2022-10-20 20:15:00  NaN
# 2022-10-20 21:15:00 2022-10-20 21:15:00  NaN
# 2022-10-20 22:15:00 2022-10-20 22:15:00  NaN
# 2022-10-20 23:15:00 2022-10-20 23:15:00  NaN
#
# [1200 rows x 2 columns]

# %%
testX_future, testY_future=create_features(df_future_dates, target_variable='Irr')
# Out:
# C:\Users\shrad\AppData\Local\Temp/ipykernel_23608/1096352164.py:11: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df['weekofyear'] = df['date'].dt.weekofyear

# %%
testX_future=testX_future[['hour','month','year']]

testX_future
# Out:
#                      hour  month  year
# Date
# 2022-09-01 00:15:00     0      9  2022
# 2022-09-01 01:15:00     1      9  2022
# 2022-09-01 02:15:00     2      9  2022
# 2022-09-01 03:15:00     3      9  2022
# 2022-09-01 04:15:00     4      9  2022
# ...                   ...    ...   ...
# 2022-10-20 19:15:00    19     10  2022
# 2022-10-20 20:15:00    20     10  2022
# 2022-10-20 21:15:00    21     10  2022
# 2022-10-20 22:15:00    22     10  2022
# 2022-10-20 23:15:00    23     10  2022
#
# [1200 rows x 3 columns]

# %%
testY_future
# Out:
# Date
# 2022-09-01 00:15:00   NaN
# 2022-09-01 01:15:00   NaN
# 2022-09-01 02:15:00   NaN
# 2022-09-01 03:15:00   NaN
# 2022-09-01 04:15:00   NaN
#                        ..
# 2022-10-20 19:15:00   NaN
# 2022-10-20 20:15:00   NaN
# 2022-10-20 21:15:00   NaN
# 2022-10-20 22:15:00   NaN
# 2022-10-20 23:15:00   NaN
# Name: Irr, Length: 1200, dtype: float64

# %%
train_size = int(len(df) * 0.75)
train, test = df[0:train_size], df[train_size:len(df)]

# %%
train_copy = train.copy()
test_copy = test.copy()
test_copy['Irr']=np.nan
test_copy=test_copy[['Year','Hour', 'Month','KW']]
train_copy['Irr']=np.nan
train_copy=train_copy[['Year','Hour', 'Month','KW']]

# %%
train = test_copy
test = train_copy

FEATURES = ['Year','Hour', 'Month']
TARGET = ['KW']
test
# Out:
#          Year  Hour  Month     KW
# 0      2021.0   0.0    1.0  91.36
# 1      2021.0   0.0    1.0  85.04
# 2      2021.0   0.0    1.0  87.52
# 3      2021.0   1.0    1.0  87.28
# 4      2021.0   1.0    1.0  89.12
# ...       ...   ...    ...    ...
# 43264  2022.0  17.0    3.0  61.20
# 43265  2022.0  17.0    3.0  61.52
# 43266  2022.0  17.0    3.0  60.88
# 43267  2022.0  18.0    3.0  59.20
# 43268  2022.0  18.0    3.0  59.28
#
# [43269 rows x 4 columns]

# %%
X_train = train[FEATURES]
y_train = train[TARGET]
X_test = test[FEATURES]
y_test = test[TARGET]
X_train
y_train
# Out:
#           KW
# 0      91.36
# 1      85.04
# 2      87.52
# 3      87.28
# 4      89.12
# ...      ...
# 43264  61.20
# 43265  61.52
# 43266  60.88
# 43267  59.20
# 43268  59.28
#
# [43269 rows x 1 columns]

# %%
import xgboost as xgb
from xgboost import XGBRegressor


reg = xgb.XGBRegressor(n_estimators=100000, early_stopping_rounds=30, learning_rate=0.001)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose = 100)

predicted_results_future = reg.predict(testX_future)
# Out:
# [0]	validation_0-rmse:100.64362	validation_1-rmse:110.92295
# [100]	validation_0-rmse:91.43415	validation_1-rmse:102.13392
# [200]	validation_0-rmse:83.13654	validation_1-rmse:94.25962
# [300]	validation_0-rmse:75.66727	validation_1-rmse:87.21515
# [400]	validation_0-rmse:68.95109	validation_1-rmse:80.92562
# [500]	validation_0-rmse:62.91965	validation_1-rmse:75.32701
# [600]	validation_0-rmse:57.51141	validation_1-rmse:70.35064
# [700]	validation_0-rmse:52.67060	validation_1-rmse:65.93776
# [800]	validation_0-rmse:48.34667	validation_1-rmse:62.03703
# [900]	validation_0-rmse:44.49382	validation_1-rmse:58.59347
# [1000]	validation_0-rmse:41.07022	validation_1-rmse:55.56286
# [1100]	validation_0-rmse:38.03763	validation_1-rmse:52.90576
# [1200]	validation_0-rmse:35.36073	validation_1-rmse:50.57972
# [1300]	validation_0-rmse:33.00711	validation_1-rmse:48.55006
# [1400]	validation_0-rmse:30.94646	validation_1-rmse:46.78148
# [1500]	validation_0-rmse:29.15053	validation_1-rmse:45.24154
# ...

# %%
df2 = df.copy()
del df2['Date']
df2
# Out:
#                  Date&Time      KW  Month    Year  Hour      Time  Week  \
# 0      2021-01-01 00:15:00   91.36    1.0  2021.0   0.0  00:15:00  53.0
# 1      2021-01-01 00:30:00   85.04    1.0  2021.0   0.0  00:30:00  53.0
# 2      2021-01-01 00:45:00   87.52    1.0  2021.0   0.0  00:45:00  53.0
# 3      2021-01-01 01:00:00   87.28    1.0  2021.0   1.0  01:00:00  53.0
# 4      2021-01-01 01:15:00   89.12    1.0  2021.0   1.0  01:15:00  53.0
# ...                    ...     ...    ...     ...   ...       ...   ...
# 57687  2022-08-24 23:00:00  118.64    8.0  2022.0  23.0  23:00:00  34.0
# 57688  2022-08-24 23:15:00  109.92    8.0  2022.0  23.0  23:15:00  34.0
# 57689  2022-08-24 23:30:00  108.88    8.0  2022.0  23.0  23:30:00  34.0
# 57690  2022-08-24 23:45:00  108.16    8.0  2022.0  23.0  23:45:00  34.0
# 57691  2022-08-25 00:00:00  104.24    8.0  2022.0   0.0  00:00:00  34.0
#
#              Day
# 0         Friday
# 1         Friday
# 2         Friday
# 3         Friday
# ...

# %%
import matplotlib.pyplot as plt 
plt.figure(figsize=(13,8))
plt.plot(list(predicted_results_future))
plt.title("Predicted")
plt.ylabel("Irr")
plt.legend(('predicted'))
plt.show()

df_future_dates_copy['Prediction'] = predicted_results_future
Irr_all_future = pd.concat([df2, df_future_dates_copy], sort=False)

# Future Graph 
Overview_Complete_Data_And_Prediction_future = Irr_all_future[['Irr','Prediction']].plot(figsize=(15, 5))

# %%
import os
import pandas as pd
import numpy as np
import xgboost
import matplotlib.pyplot as plt
from xgboost import plot_importance
from sklearn import metrics

# Dataset
df=pd.read_csv('result.csv')
#df.index = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S')

## Copied the dataset

df2 = df.copy()
del df2['Date&Time']

## Test Train Split

from pandas import read_csv
from matplotlib import pyplot
# series = read_csv('sunspots.csv', header=0, index_col=0)
X = df2
train_size = int(len(X) * 0.75)
train, test = X[0:train_size], X[train_size:len(X)]

# %%
fig, ax = plt.subplots(figsize=(15,5))
train.plot(ax=ax, label = 'Training set', title = 'Train/Test Split')
test.plot(ax=ax, label = 'Test set')
ax.axvline('2021-12-31', color='black', ls='--')
plt.show()

# %%
df=df[['Date&Time','KW','hour','DayofWeek','quarter','month','year','dayofyear']]

# %%
## Creating Features
def create_features(df, target_variable):
    
    #df['date'] = df.index
    df['hour'] = df['Date&Time'].dt.hour
    df['dayofweek'] = df['Date&Time'].dt.dayofweek
    df['quarter'] = df['Date&Time'].dt.quarter
    df['month'] = df['Date&Time'].dt.month
    df['year'] = df['Date&Time'].dt.year
    df['dayofyear'] = df['Date&Time'].dt.dayofyear
    #df['dayofmonth'] = df['date'].dt.day
    #df['weekofyear'] = df['date'].dt.weekofyear
    
    X = df[['hour','dayofweek','quarter','month','year',
           'dayofyear']]
    if target_variable:
        y = df[target_variable]
        return X, y
    return X

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def timeseries_evaluation_metrics_func(y_true, y_pred):
    print(f'MSE is : {metrics.mean_squared_error(y_true, y_pred)}')
    print(f'MAE is : {metrics.mean_absolute_error(y_true, y_pred)}')
    print(f'RMSE is : {np.sqrt(metrics.mean_squared_error(y_true, y_pred))}')
    print(f'MAPE is : {mean_absolute_percentage_error(y_true, y_pred)}')
    print(f'R2 is : {metrics.r2_score(y_true, y_pred)}',end='\n\n')

# %%
train_copy = train.copy()
test_copy = test.copy()

# %%
FEATURES = ['hour','DayofWeek','quarter','month','year','dayofyear']
TARGET = ['KW']

# %%
fi = pd.DataFrame(data=reg.feature_importances_, index=reg.feature_names_in_, columns=['Importance'])
fi
# Out:
#            Importance
# hour         0.124990
# DayofWeek    0.087799
# quarter      0.087722
# month        0.136900
# year         0.202091
# dayofyear    0.360499

# %%
fi.sort_values('Importance').plot(kind='barh', title = 'Feature Importance')
plt.show()

# %%
ax = df2[['KW']].plot(figsize=(15, 5), style='-')
df2['predictions'].plot(ax=ax, style='-')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Prediction and Original')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\anaconda\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'predictions'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
X_train = train[FEATURES]
y_train = train[TARGET]
X_test = test[FEATURES]
y_test = test[TARGET]
X_train
#y_train
# Out:
#        hour  DayofWeek  quarter  month  year  dayofyear
# 0         0          4        1      1  2021          1
# 1         0          4        1      1  2021          1
# 2         0          4        1      1  2021          1
# 3         1          4        1      1  2021          1
# 4         1          4        1      1  2021          1
# ...     ...        ...      ...    ...   ...        ...
# 43264    17          6        1      3  2022         86
# 43265    17          6        1      3  2022         86
# 43266    17          6        1      3  2022         86
# 43267    18          6        1      3  2022         86
# 43268    18          6        1      3  2022         86
#
# [43269 rows x 6 columns]

# %%
import xgboost as xgb
from xgboost import XGBRegressor


reg = xgb.XGBRegressor(n_estimators=100000, early_stopping_rounds=30, learning_rate=0.001)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose = 100)

#predicted_results_future = reg.predict(testX_future)
# Out:
# [0]	validation_0-rmse:110.91041	validation_1-rmse:100.63340
# [100]	validation_0-rmse:100.91320	validation_1-rmse:90.47112
# [200]	validation_0-rmse:91.91652	validation_1-rmse:81.35813
# [300]	validation_0-rmse:83.82608	validation_1-rmse:73.17490
# [400]	validation_0-rmse:76.55003	validation_1-rmse:65.83345
# [500]	validation_0-rmse:70.01102	validation_1-rmse:59.35190
# [600]	validation_0-rmse:64.15157	validation_1-rmse:53.54743
# [700]	validation_0-rmse:58.91508	validation_1-rmse:48.33925
# [800]	validation_0-rmse:54.23165	validation_1-rmse:43.71538
# [900]	validation_0-rmse:50.05767	validation_1-rmse:39.65759
# [1000]	validation_0-rmse:46.34744	validation_1-rmse:36.11139
# [1100]	validation_0-rmse:43.05496	validation_1-rmse:33.03770
# [1200]	validation_0-rmse:40.13140	validation_1-rmse:30.39594
# [1300]	validation_0-rmse:37.55327	validation_1-rmse:28.15220
# [1400]	validation_0-rmse:35.28307	validation_1-rmse:26.28028
# [1500]	validation_0-rmse:33.28616	validation_1-rmse:24.74450
# ...

# %%
dti = pd.date_range("2021-01-01 00:30:00", periods=20000, freq="H")
df_future_dates = pd.DataFrame(dti, columns = ['Date&Time'])
df_future_dates['KW'] = np.nan
df_future_dates.index = pd.to_datetime(df_future_dates['Date&Time'], format='%Y-%m-%d %H:%M:%S')
df_future_dates_copy = df_future_dates.copy()
testX_future, testY_future = create_features(df_future_dates, target_variable='KW')

# %%
predicted_results_future = reg.predict(testX_future)

# %%
plt.figure(figsize=(13,8))
plt.plot(list(predicted_results_future))
plt.title("Predicted")
plt.ylabel("Irr")
plt.legend(('predicted'))
plt.show()

df_future_dates_copy['Prediction'] = predicted_results_future
Irr_all_future = pd.concat([df2, df_future_dates_copy], sort=False)

# Future Graph 
Overview_Complete_Data_And_Prediction_future = Irr_all_future[['KW','Prediction']].plot(figsize=(15, 5))
